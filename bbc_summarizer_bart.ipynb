# %% [markdown]
# # Text Summarizer using BART

# %% [markdown]
# ### Importing all the prerequisite libraries

# %%
import os
import time
import glob
import pathlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import math

from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from peft import get_peft_config, get_peft_model, LoraConfig, TaskType
from transformers import BitsAndBytesConfig
from transformers import BartTokenizer, BartModel, BartForConditionalGeneration

import json


from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from sklearn.model_selection import train_test_split
from termcolor import colored
import textwrap

from transformers import AdamW

from tqdm.auto import tqdm

# %% [markdown]
# # Load the dataset

# %%
from datasets import load_dataset
from torch.utils.data import DataLoader

working_dir = os.getcwd()

# article_path, summaries_path, categories_list, filename_, categories_list = [], [], [], [], []
articles_path = os.path.join(working_dir, "BBC News Summary", "News Articles")
summaries_path = os.path.join(working_dir, "BBC News Summary", "Summaries")
categories_list = ['sport', 'entertainment', 'politics', 'business', 'tech']

# %%
def read_files(articles_path, summaries_path, categories_list=['sport', 'entertainment', 'politics', 'business', 'tech'], encoding = "ISO-8859-1"):
  articles=[]
  summaries=[]
  categories = []
  for category in categories_list:
    article_paths = glob.glob(os.path.join(articles_path, category, '*.txt'), recursive=True)
    print(f"this is article paths: {article_paths}")
    summary_paths = glob.glob(os.path.join(summaries_path, category, '*.txt'), recursive=True)

    print(f'found {len(article_paths)} file in articles/{category} folder, {len(summary_paths)} file in summaries/{category}' )

    if len(article_paths) != len(summary_paths):
      print('number of files is not equal')
      return

    #check if each article has a summary
    for idx_file in range(len(article_paths)):
      categories.append(category)
      with open(article_paths[idx_file], mode = 'r', encoding = encoding) as file:
        articles.append(file.read())

      with open(summary_paths[idx_file], mode = 'r', encoding = encoding) as file:
        summaries.append(file.read())
  print(f'total {len(articles)} file in articles folders, {len(summaries)} file in summaries folders')
  return articles, summaries, categories

# %%
articles, summaries, categories = read_files(articles_path, summaries_path, categories_list)
# Out:
# this is article paths: ['c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\001.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\002.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\003.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\004.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\005.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\006.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\007.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\008.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\009.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\010.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\011.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\012.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\013.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\014.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\015.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\016.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\017.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\018.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\019.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\020.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\021.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\022.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\023.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\024.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\025.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\026.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\027.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\028.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\029.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\030.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\031.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\032.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\sport\\033.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surre ...
# found 511 file in articles/sport folder, 511 file in summaries/sport
# this is article paths: ['c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\001.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\002.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\003.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\004.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\005.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\006.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\007.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\008.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\009.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\010.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\011.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\012.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\013.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\014.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\015.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\016.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\017.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\018.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\019.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\020.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\021.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\022.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\023.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\024.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\025.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\026.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\027.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\028.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\029.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\030.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\entertainment\\031.txt', 'c:\\Users\\seoeunl\\Desktop\\Universit ...
# found 386 file in articles/entertainment folder, 386 file in summaries/entertainment
# this is article paths: ['c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\001.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\002.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\003.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\004.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\005.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\006.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\007.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\008.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\009.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\010.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\011.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\012.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\013.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\014.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\015.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\016.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\017.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\018.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\019.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\020.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\021.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\022.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\023.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\024.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\025.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\026.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\027.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\028.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\029.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\030.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\031.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\politics\\032.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC ...
# found 417 file in articles/politics folder, 417 file in summaries/politics
# this is article paths: ['c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\001.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\002.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\003.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\004.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\005.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\006.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\007.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\008.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\009.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\010.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\011.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\012.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\013.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\014.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\015.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\016.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\017.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\018.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\019.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\020.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\021.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\022.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\023.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\024.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\025.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\026.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\027.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\028.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\029.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\030.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\031.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\business\\032.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC ...
# found 510 file in articles/business folder, 510 file in summaries/business
# this is article paths: ['c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\001.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\002.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\003.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\004.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\005.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\006.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\007.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\008.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\009.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\010.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\011.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\012.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\013.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\014.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\015.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\016.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\017.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\018.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\019.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\020.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\021.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\022.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\023.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\024.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\025.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\026.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\027.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\028.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\029.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\030.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\031.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\032.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summary\\News Articles\\tech\\033.txt', 'c:\\Users\\seoeunl\\Desktop\\University of Surrey\\2023-2024\\FYP2\\BBC News Summ ...
# found 401 file in articles/tech folder, 401 file in summaries/tech
# total 2225 file in articles folders, 2225 file in summaries folders

# %%
df = pd.DataFrame({'articles':articles, 'summaries':summaries, 'categories':categories}, )
df
# Out:
#                                                articles  \
# 0     Claxton hunting first major medal\n\nBritish h...
# 1     O'Sullivan could run in Worlds\n\nSonia O'Sull...
# 2     Greene sets sights on world title\n\nMaurice G...
# 3     IAAF launches fight against drugs\n\nThe IAAF ...
# 4     Dibaba breaks 5,000m world record\n\nEthiopia'...
# ...                                                 ...
# 2220  BT program to beat dialler scams\n\nBT is intr...
# 2221  Spam e-mails tempt net shoppers\n\nComputer us...
# 2222  Be careful how you code\n\nA new European dire...
# 2223  US cyber security chief resigns\n\nThe man mak...
# 2224  Losing yourself in online gaming\n\nOnline rol...
#
#                                               summaries categories
# 0     For the first time, Claxton has only been prep...      sport
# 1     The participation of O'Sullivan, currentily tr...      sport
# 2     I think when I was coming up I would say there...      sport
# 3     "I am very happy to see you all, members of th...      sport
# 4     Ethiopia's Tirunesh Dibaba set a new world rec...      sport
# ...                                                 ...        ...
# 2220  BT is introducing two initiatives to help beat...       tech
# 2221  A third of them read unsolicited junk e-mail a...       tech
# 2222  This goes to the heart of the European project...       tech
# 2223  Amit Yoran was director of the National Cyber ...       tech
# 2224  He says that in the world of online gaming suc...       tech
#
# [2225 rows x 3 columns]

# %%
category_sizes = df.groupby('categories').size()
sns.barplot(x=category_sizes.index, y= category_sizes)
plt.show()

# %%
# get length of each article and summary for analysis
df['articles_length'] = df['articles'].apply(lambda x : len(x.split()))
df['summaries_length'] = df['summaries'].apply(lambda x : len(x.split()))

# %%
df
# Out:
#                                                articles  \
# 0     Claxton hunting first major medal\n\nBritish h...
# 1     O'Sullivan could run in Worlds\n\nSonia O'Sull...
# 2     Greene sets sights on world title\n\nMaurice G...
# 3     IAAF launches fight against drugs\n\nThe IAAF ...
# 4     Dibaba breaks 5,000m world record\n\nEthiopia'...
# ...                                                 ...
# 2220  BT program to beat dialler scams\n\nBT is intr...
# 2221  Spam e-mails tempt net shoppers\n\nComputer us...
# 2222  Be careful how you code\n\nA new European dire...
# 2223  US cyber security chief resigns\n\nThe man mak...
# 2224  Losing yourself in online gaming\n\nOnline rol...
#
#                                               summaries categories  \
# 0     For the first time, Claxton has only been prep...      sport
# 1     The participation of O'Sullivan, currentily tr...      sport
# 2     I think when I was coming up I would say there...      sport
# 3     "I am very happy to see you all, members of th...      sport
# 4     Ethiopia's Tirunesh Dibaba set a new world rec...      sport
# ...                                                 ...        ...
# 2220  BT is introducing two initiatives to help beat...       tech
# 2221  A third of them read unsolicited junk e-mail a...       tech
# 2222  This goes to the heart of the European project...       tech
# 2223  Amit Yoran was director of the National Cyber ...       tech
# 2224  He says that in the world of online gaming suc...       tech
#
#       articles_length  summaries_length
# 0                 211                91
# 1                 144                49
# 2                 377               177
# 3                 195                99
# 4                 161                75
# ...               ...               ...
# 2220              420               186
# 2221              357               130
# 2222             1050               475
# 2223              379               137
# 2224             2969              1430
#
# [2225 rows x 5 columns]

# %%
category_length = df.groupby('categories', 0).agg({'articles_length':'mean', 'summaries_length':'mean'})
category_length
# Out:
# C:\Users\seoeunl\AppData\Local\Temp\ipykernel_429896\883843159.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   category_length = df.groupby('categories', 0).agg({'articles_length':'mean', 'summaries_length':'mean'})
#                articles_length  summaries_length
# categories
# business            328.880392        139.929412
# entertainment       330.621762        144.049223
# politics            453.973621        195.709832
# sport               329.262231        143.187867
# tech                502.695761        213.837905

# %%
# graph the articles and summaries by categories
category_length = df.groupby('categories', 0).agg({'articles_length':'mean', 'summaries_length':'mean'})
df_m = pd.melt(category_length, ignore_index=False)
plt.figure(figsize=(8,6))
sns.barplot(x=df_m.index, y="value", hue="variable", data= df_m)
plt.show()
# Out:
# C:\Users\seoeunl\AppData\Local\Temp\ipykernel_429896\3378867931.py:2: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   category_length = df.groupby('categories', 0).agg({'articles_length':'mean', 'summaries_length':'mean'})

# %%
pd.melt(category_length, ignore_index=False).groupby('variable').mean()
# Out:
#                        value
# variable
# articles_length   389.086753
# summaries_length  167.342848

# %%
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set_theme(style='whitegrid', palette='muted', font_scale=1.2)
rcParams['figure.figsize']=16,10

# %%
df
# Out:
#                                                articles  \
# 0     Claxton hunting first major medal\n\nBritish h...
# 1     O'Sullivan could run in Worlds\n\nSonia O'Sull...
# 2     Greene sets sights on world title\n\nMaurice G...
# 3     IAAF launches fight against drugs\n\nThe IAAF ...
# 4     Dibaba breaks 5,000m world record\n\nEthiopia'...
# ...                                                 ...
# 2220  BT program to beat dialler scams\n\nBT is intr...
# 2221  Spam e-mails tempt net shoppers\n\nComputer us...
# 2222  Be careful how you code\n\nA new European dire...
# 2223  US cyber security chief resigns\n\nThe man mak...
# 2224  Losing yourself in online gaming\n\nOnline rol...
#
#                                               summaries categories  \
# 0     For the first time, Claxton has only been prep...      sport
# 1     The participation of O'Sullivan, currentily tr...      sport
# 2     I think when I was coming up I would say there...      sport
# 3     "I am very happy to see you all, members of th...      sport
# 4     Ethiopia's Tirunesh Dibaba set a new world rec...      sport
# ...                                                 ...        ...
# 2220  BT is introducing two initiatives to help beat...       tech
# 2221  A third of them read unsolicited junk e-mail a...       tech
# 2222  This goes to the heart of the European project...       tech
# 2223  Amit Yoran was director of the National Cyber ...       tech
# 2224  He says that in the world of online gaming suc...       tech
#
#       articles_length  summaries_length
# 0                 211                91
# 1                 144                49
# 2                 377               177
# 3                 195                99
# 4                 161                75
# ...               ...               ...
# 2220              420               186
# 2221              357               130
# 2222             1050               475
# 2223              379               137
# 2224             2969              1430
#
# [2225 rows x 5 columns]

# %%
df=df[['articles','summaries']]

# %%
df
# Out:
#                                                articles  \
# 0     Claxton hunting first major medal\n\nBritish h...
# 1     O'Sullivan could run in Worlds\n\nSonia O'Sull...
# 2     Greene sets sights on world title\n\nMaurice G...
# 3     IAAF launches fight against drugs\n\nThe IAAF ...
# 4     Dibaba breaks 5,000m world record\n\nEthiopia'...
# ...                                                 ...
# 2220  BT program to beat dialler scams\n\nBT is intr...
# 2221  Spam e-mails tempt net shoppers\n\nComputer us...
# 2222  Be careful how you code\n\nA new European dire...
# 2223  US cyber security chief resigns\n\nThe man mak...
# 2224  Losing yourself in online gaming\n\nOnline rol...
#
#                                               summaries
# 0     For the first time, Claxton has only been prep...
# 1     The participation of O'Sullivan, currentily tr...
# 2     I think when I was coming up I would say there...
# 3     "I am very happy to see you all, members of th...
# 4     Ethiopia's Tirunesh Dibaba set a new world rec...
# ...                                                 ...
# 2220  BT is introducing two initiatives to help beat...
# 2221  A third of them read unsolicited junk e-mail a...
# 2222  This goes to the heart of the European project...
# 2223  Amit Yoran was director of the National Cyber ...
# 2224  He says that in the world of online gaming suc...
#
# [2225 rows x 2 columns]

# %%
df=df.dropna() # remove the rows that cotain NULL values

# %%
df
# Out:
#                                                articles  \
# 0     Claxton hunting first major medal\n\nBritish h...
# 1     O'Sullivan could run in Worlds\n\nSonia O'Sull...
# 2     Greene sets sights on world title\n\nMaurice G...
# 3     IAAF launches fight against drugs\n\nThe IAAF ...
# 4     Dibaba breaks 5,000m world record\n\nEthiopia'...
# ...                                                 ...
# 2220  BT program to beat dialler scams\n\nBT is intr...
# 2221  Spam e-mails tempt net shoppers\n\nComputer us...
# 2222  Be careful how you code\n\nA new European dire...
# 2223  US cyber security chief resigns\n\nThe man mak...
# 2224  Losing yourself in online gaming\n\nOnline rol...
#
#                                               summaries
# 0     For the first time, Claxton has only been prep...
# 1     The participation of O'Sullivan, currentily tr...
# 2     I think when I was coming up I would say there...
# 3     "I am very happy to see you all, members of th...
# 4     Ethiopia's Tirunesh Dibaba set a new world rec...
# ...                                                 ...
# 2220  BT is introducing two initiatives to help beat...
# 2221  A third of them read unsolicited junk e-mail a...
# 2222  This goes to the heart of the European project...
# 2223  Amit Yoran was director of the National Cyber ...
# 2224  He says that in the world of online gaming suc...
#
# [2225 rows x 2 columns]

# %%
train_df, temp_df = train_test_split(df, test_size=0.2)
val_df, test_df=train_test_split(temp_df, test_size=0.5)

# %%
from huggingface_hub import notebook_login

# notebook_login()

# %%
model_checkpoint = "facebook/bart-base"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# model = BartForConditionalGeneration.from_pretrained(model_checkpoint)

# %% [markdown]
# # Preprocessing the data: tokenization

# %%
# # Tokenizing the articles
# article_tokens=[]
# for a in df['articles']:
#     article_tokens.append(tokenizer(a))
# article_tokens

# %%
# # Tokenizing the summaries
# summary_tokens=[]
# for s in df['summaries']:
#     summary_tokens.append(tokenizer(s))
# summary_tokens

# %%
# print(f"this is the number of the articles: {len(df['articles'])}")

# %%
# print(f"this is the number of the summaries: {len(df['summaries'])}")

# %%
# print(f"this is an article: \n{df['articles'][0]}")

# %%
# art = [str(i) for i in df['articles'].tolist()]
# sum = [str(i) for i in df['summaries'].tolist()]
# sum[0]

# %%
# print(f"This is a list of articles in string format: \n{art}")
# print(f"This is a list of summaries in string format: \n{sum}")

# print(art[0])

# %% [markdown]
# # Preprocessing the data

# %%
# max_input_length = 4096
# max_target_length = 128

# def preprocess_function():
#     art = [str(i) for i in df['articles'].tolist()]
#     model_inputs = tokenizer(art)
    
#     sum = [str(i) for i in df['summaries'].tolist()]
#     labels = tokenizer(sum)

#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs


    # article_tokens=[]
    # for a in df['articles']:
    #     article_tokens.append(tokenizer(a))
    # model_inputs = article_tokens
    
    # Setup the tokenizer for targets
    # summary_tokens=[]
    # for s in df['summaries']:
    #     summary_tokens.append(tokenizer(s))
    # labels = summary_tokens

    # print("INPUT:", model_inputs[0])

# max_target_length = 128

# def preprocess_function(examples):
#     for i in range(len(df['articles'])):
#         max_input_length = len(df['articles'][i])
#         inputs = [article for article in df['articles']]
#         model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

#     # Setup the tokenizer for targets
#     labels = tokenizer(text_target=token_val, max_length=max_target_length, truncation=True)

#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs

# max_input_length = 2048
# max_target_length = 128

# def preprocess_function(examples):
#     inputs = [article for article in df['articles']]
#     model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

#     # Setup the tokenizer for targets
#     labels = tokenizer(text_target=token_val, max_length=max_target_length, truncation=True)

#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs

# %%
# preprocess_function()

# %%
# tokenized_datasets = df['articles', 'summaries'].map(preprocess_function, batched=True)

# %% [markdown]
# # Creating pytorch datasets and preprocessing

# %%
#creating pytorch dataset
class NewsSummaryDataset(Dataset):
  def __init__(self, data: pd.DataFrame, tokenizer:AutoTokenizer, text_max_token_len: int = 512, summary_max_token_len: int = 128):
    self.tokenizer = tokenizer
    self.data = data
    self.text_max_token_len = text_max_token_len
    self.summary_max_token_len = summary_max_token_len
  def __len__(self):
    return len(self.data)

  def __getitem__(self,index: int):
    data_row = self.data.iloc[index]

    text = data_row['articles']

    text_encoding = tokenizer(
        text,
        max_length=self.text_max_token_len, #max length=512
        padding='max_length',
        truncation=True,
        return_attention_mask = True,
        add_special_tokens=True,
        return_tensors='pt'
    )
    summary_encoding = tokenizer(
        data_row['summaries'],
        max_length=self.summary_max_token_len,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    )

    labels = summary_encoding['input_ids']
    # Ensure we have correct labels for T5 generation
    labels[labels==0] = -100 

    return dict(
        text=text,
        summary=data_row['summaries'],
        text_input_ids=text_encoding['input_ids'].flatten(),
        text_attention_mask=text_encoding['attention_mask'].flatten(),
        labels=labels.flatten(),
        labels_attention_mask=summary_encoding['attention_mask'].flatten()
    )

# %%
test_df
# Out:
#                                                articles  \
# 1309  Sainsbury's Labour election gift\n\nScience Mi...
# 746   Franz Ferdinand's art school lesson\n\nScottis...
# 619   Band Aid retains number one spot\n\nThe charit...
# 262   McLeish ready for criticism\n\nRangers manager...
# 736   Fox 'too reliant on reality TV'\n\nThe head of...
# ...                                                 ...
# 869   Shark Tale DVD is US best-seller\n\nOscar-nomi...
# 237   Ferguson puts faith in youngsters\n\nMancheste...
# 898   Watchdog probes e-mail deletions\n\nThe inform...
# 812   Actress Roberts takes spider role\n\nActress J...
# 2148  Mobile audio enters new dimension\n\nAs mobile...
#
#                                               summaries
# 1309  Science Minister Lord Sainsbury has made a Â£2...
# 746   The buzz about the band soon spread around the...
# 619   The charity single by Band Aid 20 has held on ...
# 262   McLeish admitted his team's defending was amat...
# 736   Five other episodes of the show had also been ...
# ...                                                 ...
# 869   Oscar-nominated animation Shark Tale has raked...
# 237   Ferguson admitted his side were well-beaten by...
# 898   All e-mails are subject to the freedom of info...
# 812   The film - a mix of live action and animation ...
# 2148  "The technology has been around on PCs and gam...
#
# [223 rows x 2 columns]

# %%
class NewsSummaryDataModule(pl.LightningDataModule):
  def __init__(
      self,
      train_df: pd.DataFrame,
      test_df: pd.DataFrame,
      tokenizer: AutoTokenizer,
      batch_size: int = 0,
      text_max_token_len: int=512,
      summary_max_token_len: int=128
  ):
      super().__init__()

      self.train_df = train_df
      self.test_df = test_df
      self.batch_size = batch_size
      self.tokenizer = tokenizer
      self.text_max_token_len = text_max_token_len
      self.summary_max_token_len = summary_max_token_len

  def setup(self, stage=None):
    self.train_dataset = NewsSummaryDataset(
        self.train_df,
        self.tokenizer,
        self.text_max_token_len,
        self.summary_max_token_len
    )
    self.test_dataset = NewsSummaryDataset(
        self.test_df,
        self.tokenizer,
        self.text_max_token_len,
        self.summary_max_token_len
    )
  def train_dataloader(self):
    return DataLoader(
        self.train_dataset,
        batch_size=self.batch_size,
        shuffle=True,
        num_workers=0
    )
  def test_dataloader(self):
    return DataLoader(
        self.test_dataset,
        batch_size=self.batch_size,
        shuffle=True,
        num_workers=0
    )
  def val_dataloader(self):
    return DataLoader(
        self.test_dataset,
        batch_size=self.batch_size,
        shuffle=True,
        num_workers=0
    )

# %%
text_token_counts, summary_token_counts = [], []

for _, row in train_df.iterrows():
  text_token_count = len(tokenizer.encode(row['articles']))
  text_token_counts.append(text_token_count)

  summary_token_count = len(tokenizer.encode(row['summaries']))
  text_token_counts.append(summary_token_count)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1084 > 1024). Running this sequence through the model will result in indexing errors

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
sns.histplot(text_token_counts, ax=ax1)
ax1.set_title('full text token counts')
sns.histplot(summary_token_counts, ax=ax2)
# Out:
# <Axes: >

# %%
N_EPOCHS = 8
BATCH_SIZE = 8

data_module = NewsSummaryDataModule(train_df, test_df, tokenizer, batch_size=BATCH_SIZE)

# %%
data_module

# %% [markdown]
# # Model

# %%
class NewsSummaryModel(pl.LightningModule):
  def __init__(self):
    super().__init__()
    self.model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint, return_dict=True)
  
  def forward(self, input_ids, attention_mask, decoder_attention_mask, labels=None):
    # print("FORWARD")
    output=self.model(
        input_ids,
        attention_mask=attention_mask,
        labels=labels,
        decoder_attention_mask=decoder_attention_mask
    )
  
    return output.loss, output.logits

  def training_step(self, batch, batch_size):
    # print("TRAINING")
    input_ids = batch['text_input_ids']
    attention_mask = batch['text_attention_mask']
    labels = batch['labels']
    labels_attention_mask = batch['labels_attention_mask']

    loss, outputs = self(
        input_ids=input_ids,
        attention_mask=attention_mask,
        decoder_attention_mask= labels_attention_mask,
        labels=labels
    )

    self.log("train_loss", loss, prog_bar=True, logger=True)
    return loss

  def validation_step(self, batch, batch_size):
    # print("VALIDATION")
    input_ids = batch['text_input_ids']
    attention_mask = batch['text_attention_mask']
    labels = batch['labels']
    labels_attention_mask = batch['labels_attention_mask']

    loss, outputs = self(
        input_ids=input_ids,
        attention_mask=attention_mask,
        decoder_attention_mask=labels_attention_mask,
        labels=labels
    )

    self.log("val_loss", loss, prog_bar=True, logger=True)
    return loss
  def test_step(self, batch, batch_size):
    # print("TEST")
    input_ids = batch['text_input_ids']
    attention_mask = batch['text_attention_mask']
    labels = batch['labels']
    labels_attention_mask = batch['labels_attention_mask']

    loss, outputs = self(
        input_ids=input_ids,
        attention_mask=attention_mask,
        decoder_attention_mask=labels_attention_mask,
        labels=labels
    )

    self.log("test_loss", loss, prog_bar=True, logger=True)
    return loss
  
  def configure_optimizers(self):
    optimizer = torch.optim.Adam(self.parameters(), lr=2e-5)
    return [optimizer]

# %%
model = NewsSummaryModel()

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./lightning_logs
# Out:
# Launching TensorBoard...

# %%
checkpoint_callback = ModelCheckpoint(
    dirpath='checkpoints',
    filename='best-checkpoint',
    save_top_k=1,
    verbose=True,
    monitor='val_loss',
    mode='min'
)

logger = TensorBoardLogger("lightning_logs", name='news-summary')

trainer = pl.Trainer(
    logger=logger,
    # checkpoint_callback=checkpoint_callback,
    max_epochs=N_EPOCHS,
    # gpus=1,
    # progress_bar_refresh_rate=30
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
torch.cuda.empty_cache() #clear any cache

# %%
import gc
gc.collect() #clear any garbage collector
# Out:
# 1428

# %%
# with torch.no_grad():
trainer.fit(model, data_module)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 4070 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                         | Params
# -------------------------------------------------------
# 0 | model | BartForConditionalGeneration | 139 M
# -------------------------------------------------------
# 139 M     Trainable params
# 0         Non-trainable params
# 139 M     Total params
# 557.682   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# Training: 0it [00:00, ?it/s]
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# TRAINING
# FORWARD
# Validation: 0it [00:00, ?it/s]
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# VALIDATION
# FORWARD
# `Trainer.fit` stopped: `max_epochs=1` reached.

# %%
PATH = "\model_bart.pt"

torch.save({
            'epoch': N_EPOCHS,
            'model_state_dict': model.state_dict(),
            }, PATH)

# %%
trained_model = NewsSummaryModel.load_from_checkpoint(
    trainer.checkpoint_callback.best_model_path #load the best model using checkpoint
)
trained_model.freeze()

# %% [markdown]
# # Summarize the text

# %%
# summarize the text
def summarizeText(text):
  text_encoding = tokenizer(
      text,
      max_length=512,
      padding='max_length',
      truncation=True,
      return_attention_mask=True,
      add_special_tokens=True,
      return_tensors='pt'
  )

  generated_ids = trained_model.model.generate(
      input_ids=text_encoding['input_ids'],
      attention_mask = text_encoding['attention_mask'],
      max_length=150, # maximum output text length
      num_beams=2, #using beam search
      repetition_penalty=2.5,
      length_penalty=1.0,
      early_stopping=True
  )

#decoded values
  preds = [
      tokenizer.decode(gen_id,skip_special_tokens=True, clean_up_tokenization_spaces=True)
      for gen_id in generated_ids
  ]
  return "".join(preds)

# %% [markdown]
# # Evaluation using Rouge

# %%
import evaluate

rouge_score = evaluate.load('rouge')

# %%
def compute_metrics():
# predictions, labels = eval_pred
    
    # Decode generated summaries into text
    # preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    
    # Replace -100 in the labels as we can't decode them
    # labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    
    # Decode reference summaries into text
    # decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # ROUGE expects a newline after each sentence
    # decoded_preds = ["\n".join(sent_tokenize(pred.strip())) for pred in decoded_preds]
    # decoded_labels = ["\n".join(sent_tokenize(label.strip())) for label in decoded_labels]
    
    # Compute ROUGE scores
    # result = rouge_score.compute(predictions=preds, references=decoded_labels, use_stemmer=True)
    result = rouge_score.compute(predictions=preds, use_stemmer=True)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
def print_summary():
    data = []
    for r in range(len(test_df)):
        row = test_df.iloc[r]
        art_row = row['articles']
        sum_row = row['summaries'] #actual summary from the dataset
        gen_summary = summarizeText(art_row) #generated summary for article
        score = rouge_score.compute(predictions=[gen_summary], references=[sum_row])
        scores = {k: round(v, 4) for k, v in score.items()}
        data.append([art_row, sum_row, gen_summary, scores])
        print(f"'>>> Article: {art_row}'")
        print(f"\n'>>> Summary: {sum_row}'")
        print(f"\n'>>> Generated Summary: {gen_summary}'")
        print(f"\n'>>> ROUGE Score: {scores}'")
    result=pd.DataFrame(data, columns=['articles', 'original summary', "generated summary", "score"])
    return result

# %%
result_bart = print_summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 result = print_summary()
#
# Cell In[62], line 8, in print_summary()
#       6 sum_row = row['summaries'] #actual summary from the dataset
#       7 gen_summary = summarizeText(art_row) #generated summary for article
# ----> 8 score = rouge_score.compute(predictions=[gen_summary], references=[sum_row])
#       9 scores = {k: round(v, 4) for k, v in score.items()}
#      10 data.append([art_row, sum_row, gen_summary, scores])
#
# NameError: name 'rouge_score' is not defined

# %%
pd.DataFrame.from_records(result_bart).to_csv('results_bart.csv', header=["article","original_summary","generated summary","rouge_score"], index=False)

# %% [markdown]
# # Fine Tuning

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model_name = "facebook/bart-base"
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base")

peft_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM, inference_mode=False, r=8, lora_alpha=32, lora_dropout=0.1
)

model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb_config)
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
